# %% [markdown]
# <a href="https://colab.research.google.com/github/00kang/gis_algorithm/blob/main/July/07_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h3> 덱

# %% [markdown]
# ![Untitled00.png](data:image/png;base64,...)

# %% [markdown]
# ![Untitled4.png](data:image/png;base64,...)

# %% [markdown]
# <h3> 풀이1 _ 클래스화

# %%
from collections import deque

class StackAndQueue:
    def __init__(self, data_type="stack"):
        self.array = deque()
        self.data_type = data_type #default가 stack타입

    def push(self, num):
        self.array.append(num)

    def pop(self):
        if self.is_empty():
            return -1
        if self.is_stack():
            return self.array.pop()
        return self.array.popleft()

    def empty(self):
        return int(self.is_empty())

    def size(self):
        return len(self.array)

    def top(self):
        if not self.is_stack() or self.is_empty():
            return -1
        return self.array[-1]

    def front(self):
        if self.is_stack() or self.is_empty():
            return -1
        return self.array[0]

    def back(self):
        if self.is_stack() or self.is_empty():
            return -1
        return self.array[-1]

    #class 내부에서 사용되는 함수들
    def is_empty(self):
        return self.size() == 0

    def is_stack(self):
        return self.data_type == "stack"

def run_cmd_with_deque(command, data_obj):
    cmd_type = command[0]

    if cmd_type == "push":
        _, num = command
        data_obj.push(num)

    elif cmd_type == "pop":
        print(data_obj.pop())

    elif cmd_type == "empty":
        print(data_obj.empty())

    elif cmd_type == "size":
        print(data_obj.size())

    elif cmd_type == "top":
        print(data_obj.top())

    elif cmd_type == "front":
        print(data_obj.front())

    elif cmd_type == "back":
         print(data_obj.back())


data_type = input()
n = int(input())
data_obj = StackAndQueue(data_type)

for _ in range(n):
    run_cmd_with_deque(input().split(), data_obj)
# Out:
# stack
# 14
# push 1
# push 2
# top
# 2
# size
# 2
# empty
# 0
# pop
# 2
# pop
# 1
# pop
# -1
# size
# 0
# empty
# 1
# pop
# -1
# push 3
# empty
# 0
# top
# 3

# %%
from collections import deque

class StackAndQueue:
    def __init__(self, data_type="stack"):
        self.array = deque()
        self.data_type = data_type #default가 stack타입

    def push(self, num):
        self.array.append(num)

    def pop(self):
        if self.is_empty():
            return -1
        if self.is_stack():
            return self.array.pop()
        return self.array.popleft()

    def empty(self):
        return int(self.is_empty())

    def size(self):
        return len(self.array)

    def top(self):
        if not self.is_stack() or self.is_empty():
            return -1
        return self.array[-1]

    def front(self):
        if self.is_stack() or self.is_empty():
            return -1
        return self.array[0]

    def back(self):
        if self.is_stack() or self.is_empty():
            return -1
        return self.array[-1]

    #class 내부에서 사용되는 함수들
    def is_empty(self):
        return self.size() == 0

    def is_stack(self):
        return self.data_type == "stack"

def run_cmd_with_deque(command, data_obj):
    cmd_type = command[0]

    if cmd_type == "push":
        _, num = command
        data_obj.push(num)

    elif cmd_type == "pop":
        print(data_obj.pop())

    elif cmd_type == "empty":
        print(data_obj.empty())

    elif cmd_type == "size":
        print(data_obj.size())

    elif cmd_type == "top":
        print(data_obj.top())

    elif cmd_type == "front":
        print(data_obj.front())

    elif cmd_type == "back":
         print(data_obj.back())


data_type = input()
n = int(input())
data_obj = StackAndQueue(data_type)

for _ in range(n):
    run_cmd_with_deque(input().split(), data_obj)
# Out:
# queue
# 15
# push 1
# push 2
# front
# 1
# back
# 2
# size
# 2
# empty
# 0
# pop
# 1
# pop
# 2
# pop
# -1
# size
# 0
# empty
# 1
# pop
# -1
# push 3
# empty
# 0
# front
# 3
